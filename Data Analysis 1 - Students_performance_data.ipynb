# %%
#load libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

#data importing
da1=pd.read_csv("StudentsPerformance.csv")
da1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#to find the dimension of data
print(da1.shape)
# Out:
# (1000, 8)

# %%
da1.shape
# Out:
# (1000, 8)

# %%
#print first 5 rows
da1.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#print first 2 rows
da1.head(2)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88

# %%
#print last 3 rows
da1.tail(3)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
#to get column names 
da1.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
#checking null values
da1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
da1.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# This data is of performance score of some students, data contains 1000 rows and 8 columns
# using info code we can identifiy there is no null values in the data.
# Students are seperated into some groups (group A, B,C D)
# Their parents level of education is given
# here we can see how many of them completed the test preperation course
# and reding score and writing score of the studnets is also given in data.

# %% [markdown]
# ## Data Analysis / Data Visualization using matplotlib and seaborn

# %% [markdown]
# Bar plt
# Pie chart
# Histogram
# Boxplot
# Scatterpot
# Heatmap
# Multiple bar
# Stacked bar

# %%
a=da1['gender'].value_counts()
a
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
da1['gender'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
da1['gender'].value_counts(normalize = True)
da1['gender'].value_counts(dropna = False).plot.bar(color = 'magenta')
plt.title('Comparison of Gender')
plt.xlabel('gender')
plt.ylabel('count')
plt.show()

# %%
a.plot(kind="bar", color='lawngreen')
plt.title('Comparison of Gender')
plt.xlabel('gender')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
#autopct will bring the percentage values in the graph

a.plot(kind="pie", colors=['lawngreen', 'cyan'], autopct='%1.2f%%')
# Out:
# <AxesSubplot:ylabel='gender'>

# %% [markdown]
# Female is 518 and male 482
#
# 52% of students in data is female and 48% are male

# %%
b=da1['race/ethnicity'].value_counts()
b

b.plot(kind='bar', color='cyan')
plt.title('Comparison of groups')
plt.xlabel('Groups')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# group C Contains more students and group A contains less

# %%
c=da1['parental level of education'].value_counts()
c

c.plot(kind='bar', color='orchid')
plt.title('Comparison of Parental Education')
plt.xlabel('Degree')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
d=da1['lunch'].value_counts()
d

d.plot(kind='bar', color='orchid')
plt.title('Comparison of lunch')
plt.xlabel('types of lunch')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
d.plot(kind='pie', colors=['orchid', 'black'])
plt.title('Test preperation course')
# Out:
# Text(0.5, 1.0, 'Test preperation course')

# %%
e=da1['test preparation course'].value_counts()
e

e.plot(kind='bar', color='aquamarine')
plt.title('Test preperation course')
# Out:
# Text(0.5, 1.0, 'Test preperation course')

# %%
e.plot(kind='pie', colors=['aquamarine', 'black'])
# Out:
# <AxesSubplot:ylabel='test preparation course'>

# %% [markdown]
# # continuous variable analysis

# %%
da1.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# Average score of Math, reading and writing is 66, 69 and 68 respectively
#
# the maximum score is 100 in all paper
#
# Minimum score of math is 0, Minimum score of reading and writing is 17 and 15 respectively

# %%
da1['math score'].value_counts()

#da1['math score'].value_counts(normalize = True)
#da1['math score'].value_counts(dropna = False).plot.bar(figsize = (18, 10))
#plt.title('Comparison of math scores')
#plt.xlabel('score')
#plt.ylabel('count')
#plt.show()
# Out:
# 65    36
# 62    35
# 69    32
# 59    32
# 61    27
#       ..
# 24     1
# 28     1
# 33     1
# 18     1
# 8      1
# Name: math score, Length: 81, dtype: int64

# %%
da1['math score'].value_counts().plot.bar(figsize=(20,5))
plt.title('Comparison of math scores')
plt.xlabel('score')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
da1['reading score'].value_counts().plot.bar(figsize=(20,5), color='green')
plt.title('Comparison of Reading Score')
plt.xlabel('score')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
da1['writing score'].value_counts().plot.bar(figsize=(20,5), color='magenta')
plt.title('Comparison of Writing Score')
plt.xlabel('score')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
#Histogram for continues variables
#histogram shows the normality of data

da1.hist(color='brown')
plt.show()

# %%
#boxplot
#boxplot shows the outliers in each continues variable
da1.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Comparing 2 variables in the data

# %%
#scatterplot

sns.pairplot(da1)

# %%
#correlation

da1.corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
#heatmap 

sns.heatmap(da1.corr(), annot=True, cmap='RdYlGn', square=True)
# Out:
# <AxesSubplot:>

# %%
#comparison of gender and race/ethnicity
#crosstabulation

aa=pd.crosstab(da1['gender'], da1['race/ethnicity'])
aa
# Out:
# race/ethnicity  group A  group B  group C  group D  group E
# gender
# female               36      104      180      129       69
# male                 53       86      139      133       71

# %%
#multiple bar diagram

aa.plot(kind='bar', cmap='copper')
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
#stacked bar diagram

x = pd.crosstab(da1['gender'], da1['race/ethnicity'])
x.div(x.sum(1).astype(float), axis = 0).plot(kind = 'bar', stacked = True, figsize = (4, 4))
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
#multiple bar diagram using seaborn library

sns.countplot(x='race/ethnicity', data=da1, hue='gender', palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='count'>

# %%
bb=pd.crosstab(da1['gender'],da1['lunch'])
bb.plot(kind='bar',cmap='Dark2')
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
cc=pd.crosstab(da1['gender'],da1['parental level of education'])
cc.plot(kind='bar',cmap='RdGy')
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
cc=pd.crosstab(da1['parental level of education'],da1['gender'])
cc.plot(kind='bar',cmap='RdGy')
# Out:
# <AxesSubplot:xlabel='parental level of education'>

# %%
dd=pd.crosstab(da1['gender'],da1['test preparation course'])
dd.plot(kind='bar',cmap='jet')
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
sns.countplot(x='race/ethnicity', data=da1, hue='test preparation course', palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='count'>

# %%
da1.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
sns.countplot(x='race/ethnicity', data=da1, hue='parental level of education', palette='flag')
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='count'>

# %%
sns.countplot(x='race/ethnicity', data=da1, hue='lunch', palette='afmhot')
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='count'>

# %%
sns.countplot(x='lunch', data=da1, hue='parental level of education', palette='icefire')
# Out:
# <AxesSubplot:xlabel='lunch', ylabel='count'>

# %%
sns.countplot(x='lunch', data=da1, hue='test preparation course', palette='cool')
# Out:
# <AxesSubplot:xlabel='lunch', ylabel='count'>

# %%
sns.countplot(x = 'test preparation course', data = da1, hue = 'parental level of education', palette = 'dark')
plt.show()
